# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Wald_Test_Trial_WorkUp.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['black', 'white','hispanic', 'asian'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0   8.0   male          black                        1
# 1   8.0   male          black                        1
# 2   8.0   male          black                        1
# 3   8.0   male          black                        1
# 4   8.0   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.215290
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 1800
# Model:                               Logit   Df Residuals:                     1795
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 27 Jan 2025   Pseudo R-squ.:                 0.01105
# Time:                             13:17:32   Log-Likelihood:                -387.52
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Wald_Test_Trial_WorkUp.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['white', 'black','hispanic', 'asian'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0   8.0   male          black                        1
# 1   8.0   male          black                        1
# 2   8.0   male          black                        1
# 3   8.0   male          black                        1
# 4   8.0   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.215290
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 1800
# Model:                               Logit   Df Residuals:                     1795
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 27 Jan 2025   Pseudo R-squ.:                 0.01105
# Time:                             13:17:48   Log-Likelihood:                -387.52
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Wald_Test_Trial_WorkUp.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['hispanic', 'black','white', 'asian'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0   8.0   male          black                        1
# 1   8.0   male          black                        1
# 2   8.0   male          black                        1
# 3   8.0   male          black                        1
# 4   8.0   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.215290
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 1800
# Model:                               Logit   Df Residuals:                     1795
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 27 Jan 2025   Pseudo R-squ.:                 0.01105
# Time:                             13:18:17   Log-Likelihood:                -387.52
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Wald_Test_Trial_WorkUp.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['asian', 'black','white', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0   8.0   male          black                        1
# 1   8.0   male          black                        1
# 2   8.0   male          black                        1
# 3   8.0   male          black                        1
# 4   8.0   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.215290
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 1800
# Model:                               Logit   Df Residuals:                     1795
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 27 Jan 2025   Pseudo R-squ.:                 0.01105
# Time:                             13:18:32   Log-Likelihood:                -387.52
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/WorkUp_2.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['asian', 'black','white', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0     1   male          black                        1
# 1     1   male          black                        0
# 2     1   male          black                        1
# 3     1   male          black                        1
# 4     1   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.249950
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 2000
# Model:                               Logit   Df Residuals:                     1995
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 10 Feb 2025   Pseudo R-squ.:                0.004360
# Time:                             14:18:42   Log-Likelihood:                -499.90
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/WorkUp_2.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['black', 'asian','white', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0     1   male          black                        1
# 1     1   male          black                        0
# 2     1   male          black                        1
# 3     1   male          black                        1
# 4     1   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.249950
#          Iterations 7
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 2000
# Model:                               Logit   Df Residuals:                     1995
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 10 Feb 2025   Pseudo R-squ.:                0.004360
# Time:                             14:19:03   Log-Likelihood:                -499.90
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Treatment_2.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['black', 'asian','white', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0     1   male          black                        0
# 1     1   male          black                        1
# 2     1   male          black                        0
# 3     1   male          black                        1
# 4     1   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.535630
#          Iterations 5
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 2000
# Model:                               Logit   Df Residuals:                     1995
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 10 Feb 2025   Pseudo R-squ.:                0.001133
# Time:                             14:28:47   Log-Likelihood:                -1071.3
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Treatment_2.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['white', 'asian','black', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0     1   male          black                        0
# 1     1   male          black                        1
# 2     1   male          black                        0
# 3     1   male          black                        1
# 4     1   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.535630
#          Iterations 5
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 2000
# Model:                               Logit   Df Residuals:                     1995
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 10 Feb 2025   Pseudo R-squ.:                0.001133
# Time:                             14:29:03   Log-Likelihood:                -1071.3
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import logit

# Load the Excel file
file_path = '/Users/katherinekrieger/Desktop/Treatment_2.xlsx'
data = pd.read_excel(file_path)

# Check the data structure
print(data.head())

# Ensure the dependent variable is binary (0 or 1)
data['recommendation_presence'] = data['recommendation_presence'].astype(int)

# Set 'white' as the reference category for race_ethnicity
data['race_ethnicity'] = pd.Categorical(data['race_ethnicity'], categories=['asian', 'white','black', 'hispanic'], ordered=False)

# Fit the logistic regression model using the formula API
model = logit('recommendation_presence ~ Gender + race_ethnicity', data=data).fit()

# Print the summary of the model
print(model.summary())

# Perform Wald test for significance of each independent variable
wald_test_results = model.wald_test_terms(scalar=True)
print(wald_test_results)
# Out:
#    Case Gender race_ethnicity  recommendation_presence
# 0     1   male          black                        0
# 1     1   male          black                        1
# 2     1   male          black                        0
# 3     1   male          black                        1
# 4     1   male          black                        1
# Optimization terminated successfully.
#          Current function value: 0.535630
#          Iterations 5
#                               Logit Regression Results
# ...
# Dep. Variable:     recommendation_presence   No. Observations:                 2000
# Model:                               Logit   Df Residuals:                     1995
# Method:                                MLE   Df Model:                            4
# Date:                     Mon, 10 Feb 2025   Pseudo R-squ.:                0.001133
# Time:                             14:29:14   Log-Likelihood:                -1071.3
# ...
